# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive

# %%
# !cp /mydrive/coba/backup/yolov3_final.weights ./weights/yolov3.weights
# !cp /mydrive/coba/obj.names ./data/data.names
# !cp /mydrive/coba/test.jpg ./data/images/test.jpg
# !cp /mydrive/coba/yolov3.cfg ./cfg/yolov3.cfg
# !cp /mydrive/coba/yolov3.py ./yolov3.py
# !cp /mydrive/coba/convert_weights.py ./convert_weights.py
# !cp /mydrive/coba/utils.py ./utils.py
# !cp /mydrive/coba/image.py ./image.py

# %%
# !python yolov3.py
# Out:
# 2021-05-28 02:10:50.779216: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
# !python convert_weights.py
# Out:
# 2021-05-28 02:10:55.707609: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-28 02:10:56.913045: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-05-28 02:10:57.053425: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-28 02:10:57.054080: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-05-28 02:10:57.054129: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !python utils.py
# Out:
# 2021-05-28 02:11:09.223596: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
# !python image.py
# Out:
# 2021-05-28 02:11:15.149639: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-28 02:11:16.349983: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-05-28 02:11:16.377753: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-28 02:11:16.378346: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-05-28 02:11:16.378385: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
