# %% [markdown]
# # Cloning and Building Darknet

# %% [markdown]
# make sure use GPU

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15050, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 15050 (delta 16), reused 34 (delta 14), pack-reused 15002
# Receiving objects: 100% (15050/15050), 13.48 MiB | 21.17 MiB/s, done.
# Resolving deltas: 100% (10215/10215), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:935:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1136:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %% [markdown]
# # Download pretrained YOLOv3 weights

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2021-05-20 22:17:07--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   104MB/s    in 2.3s
#
# 2021-05-20 22:17:09 (104 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %% [markdown]
# # Uploading Google Drive Files to Use

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /content
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# '[drivedrama.asia] Hello Monster (540p).rar'   MioFiles      training
# 'Meong(dot)Club'			       moe-files
#  minitab				      'Open Drive'

# %%
# %cd darknet
# Out:
# /content/darknet

# %% [markdown]
# # Moving Custom Dataset to Cloud VM

# %%
# !ls /mydrive/training/
# Out:
# backup	obj.data  obj.names  obj.zip  training.py  yolov3.cfg

# %%
# !cp /mydrive/training/obj.zip ../

# %%
# !unzip ../obj.zip -d data/
# Out:
# Archive:  ../obj.zip
#    creating: data/obj/
#   inflating: data/obj/alpukat_training_001.jpg
#   inflating: data/obj/alpukat_training_001.txt
#   inflating: data/obj/alpukat_training_002.jpg
#   inflating: data/obj/alpukat_training_002.txt
#   inflating: data/obj/alpukat_training_003.jpg
#  extracting: data/obj/alpukat_training_003.txt
#   inflating: data/obj/alpukat_training_004.jpg
#   inflating: data/obj/alpukat_training_004.txt
#   inflating: data/obj/alpukat_training_005.jpg
#   inflating: data/obj/alpukat_training_005.txt
#   inflating: data/obj/alpukat_training_006.jpg
#   inflating: data/obj/alpukat_training_006.txt
#   inflating: data/obj/alpukat_training_007.jpg
#   inflating: data/obj/alpukat_training_007.txt
#   inflating: data/obj/alpukat_training_008.jpg
#   inflating: data/obj/alpukat_training_008.txt
#   inflating: data/obj/alpukat_training_009.jpg
#   inflating: data/obj/alpukat_training_009.txt
#   inflating: data/obj/alpukat_training_010.jpg
# ...

# %% [markdown]
# # Configuring Files for Training

# %% [markdown]
# Upload config file from google drive

# %%
# !cp /mydrive/training/yolov3.cfg ./cfg

# %% [markdown]
# Upload obj.data and obj.names from google drive

# %%
# !cp /mydrive/training/obj.names ./data
# !cp /mydrive/training/obj.data  ./data

# %% [markdown]
# Upload general_trainn.py from google drive

# %%
# !cp /mydrive/training/training.py ./

# %%
# !python training.py

# %% [markdown]
# check that train.txt at the right folder

# %%
# !ls data/
# Out:
# 9k.tree     eagle.jpg	 imagenet.labels.list	   obj.data	     scream.jpg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  obj.names	     train.txt
# coco.names  goal.txt	 labels			   openimages.names  voc.names
# dog.jpg     horses.jpg	 obj			   person.jpg

# %% [markdown]
# # Download pre-trained weights for the convolutional layers.

# %%
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2021-05-20 22:19:06--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  91.9MB/s    in 1.7s
#
# 2021-05-20 22:19:08 (91.9 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# # It's time to training

# %%
# !./darknet detector train data/obj.data cfg/yolov3.cfg darknet53.conv.74 -dont_show

# %% [markdown]
# when time is over at colab, continue with file weights at backup

# %%
# !./darknet detector train data/obj.data cfg/yolov3.cfg /mydrive/training/backup/yolov3_last.weights -dont_show
